# %% [markdown]
# <a href="https://colab.research.google.com/github/huseyingulcicek08/-Composing-squared-strings/blob/master/keras_ocr_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# !pip install -q keras-ocr

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Imports

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %% [markdown]
# # Download Weights

# %%
pipeline = keras_ocr.pipeline.Pipeline()

# %% [markdown]
# # Get Images

# %%
images = [
    keras_ocr.tools.read(img) for img in ['/content/drive/MyDrive/Colab Notebooks/asd.jpg',
                                          '/content/drive/MyDrive/Colab Notebooks/asdf.png'
                                          ]
]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[0])

# %%
plt.figure(figsize = (10,20))
plt.imshow(images[1])

# %% [markdown]
# # Get Predictions

# %%
prediction_groups = pipeline.recognize(images)

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(10, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, 
                                    predictions=predictions, 
                                    ax=ax)
